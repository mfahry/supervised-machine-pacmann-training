# %% [markdown]
# # Plotting with Python

# %%
import pandas as pd

#import library for plotting
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Outline
# - Dataset
# - Plotting Library
# - Histogram
# - KDE plot
# - Box Plot
# - Violin Plot
# - Bar Plot
# - Scatter Plot

# %% [markdown]
# ###### read data csv

# %%
hr_data = pd.read_csv("hr_data_clean.csv")

# %%
hr_data.head()
# Out:
#    Unnamed: 0  satisfaction_level  last_evaluation  number_project  \
# 0           0                0.65             0.53             2.0
# 1           1                0.80             0.86             5.0
# 2           2                0.11             0.72             7.0
# 3           3                0.72             0.87             5.0
# 4           4                0.37             0.52             2.0
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                 157.0                 3.0              0
# 1                 262.0                 6.0              0
# 2                 272.0                 4.0              0
# 3                 223.0                 5.0              0
# 4                 159.0                 3.0              0
#
#    promotion_last_5years division  salary  left
# 0                      0    sales  KOSONG     1
# 1                      0    sales  medium     1
# 2                      0   KOSONG  medium     1
# 3                      0    sales     low     1
# 4                      0    sales     low     1

# %%
hr_data = hr_data.drop(["Unnamed: 0"], axis=1)
hr_data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.65             0.53             2.0                 157.0
# 1                0.80             0.86             5.0                 262.0
# 2                0.11             0.72             7.0                 272.0
# 3                0.72             0.87             5.0                 223.0
# 4                0.37             0.52             2.0                 159.0
#
#    time_spend_company  Work_accident  promotion_last_5years division  salary  \
# 0                 3.0              0                      0    sales  KOSONG
# 1                 6.0              0                      0    sales  medium
# 2                 4.0              0                      0   KOSONG  medium
# 3                 5.0              0                      0    sales     low
# 4                 3.0              0                      0    sales     low
#
#    left
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %% [markdown]
# ###### Visualize "left" column

# %%
hr_data["left"].value_counts(normalize=True)
# Out:
# 0    0.761917
# 1    0.238083
# Name: left, dtype: float64

# %% [markdown]
# ###### custom style seaborn

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ###### Histogram

# %%
#custom = ["green","orange"]
#sns.countplot(hr_data["left"], palette=sns.color_palette(custom))
sns.countplot(hr_data["left"], palette="Accent")
sns.despine(left=True, bottom=True)

# %%
sns.countplot(hr_data["number_project"], palette="Accent")

# %% [markdown]
# #### Differentiate by column

# %%
sns.countplot(hr_data["number_project"],  hue=hr_data["left"], palette="Accent")

# %% [markdown]
# #### Histogram for Continous Data

# %%
sns.distplot(hr_data["satisfaction_level"], kde=False)

# %% [markdown]
# #### KDE Plot

# %%
sns.kdeplot(hr_data["satisfaction_level"])

# %% [markdown]
# ###### Box Plot

# %%
sns.boxplot(x=hr_data["left"], y=hr_data["satisfaction_level"], palette="Accent")

# %% [markdown]
# #### Bar Plot

# %%
sns.barplot(x=hr_data["number_project"], y=hr_data["satisfaction_level"], palette="Accent")

# %% [markdown]
# ###### Scatter Plot

# %%
sns.lmplot(x="average_montly_hours", 
           y="satisfaction_level", 
           hue="left", 
           data=hr_data, 
           fit_reg=False, 
           markers=["o","x"])
